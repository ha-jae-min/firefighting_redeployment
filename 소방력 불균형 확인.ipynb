# %%
import pandas as pd

df = pd.read_excel('/content/부산 소방서별 소방공무원 (2021).xlsx')
df
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     소방서별(1)   2021   2021.1   2021.2   2021.3   2021.4   2021.5   2021.6  \
# 0   소방서별(1)  계 (명)  소방직 (명)  소방직 (명)  소방직 (명)  소방직 (명)  소방직 (명)  소방직 (명)
# 1   소방서별(1)     소계       소계      소방감     소방준감      소방정      소방령      소방경
# 2        합계   3631     3631        -        3       16      107      239
# 3    소방재난본부    366      366        -        3        5       34       35
# 4      소방학교     36       36        -        -        -        3        6
# 5     중부소방서    273      273        -        -        1        7       18
# 6    부산진소방서    339      339        -        -        1        7       20
# 7     동래소방서    299      299        -        -        1        7       18
# 8     북부소방서    409      409        -        -        1        7       22
# ...
